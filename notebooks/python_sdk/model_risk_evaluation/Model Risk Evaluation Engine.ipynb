# %% [markdown]
# # Foundation Model Risk Evaluation using IBM watsonx.governance

# %% [markdown]
# The notebook evaluates the risk associated with a given foundation model using IBM watsonx.governance. The foundation model to evaluate can be either in IBM watsonx.ai or in an external model provider. The risk evaluation result can be stored in Governance Console or can be downloaded as a pdf file.

# %% [markdown]
# This notebook should be run in Python 3.10 or higher runtime environment.

# %% [markdown]
# ## Learning goals
#
# - Provide foundation model details hosted in IBM watsonx.ai or in external system
# - Run Model Risk Evaluation for the given foundation model
# - Generate PDF report of the evaluation result and publish results in Governance Console.

# %% [markdown]
# ## Contents
#
# - [Step 1 - Install libraries](#install)
# - [Step 2 - Configuration](#configuration)
# - [Step 3 - Foundation Model Risk Evaluation](#evaluate)
# - [Step 4 - Display the results](#display)

# %% [markdown]
# ## Install libraries<a name="install"></a>

# %% [markdown]
# ### Install the required packages

# %%
# %pip install "ibm_watsonx_gov[mre]"
# !python -m nltk.downloader stopwords
# !pip install "pydyf<0.11.0"
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Install Required System Libraries
# These libraries are required for text rendering and graphics support used by Python dependencies.

# %%
# !mamba install -c conda-forge pango cairo glib gobject-introspection libffi --yes

# %% [markdown]
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Configuration <a name="configuration"></a>

# %% [markdown]
# ## Step 1: Configure Credentials (**IBM watsonx.governance as a Service**)
#
# Use the cell below to configure your credentials for accessing **IBM watsonx.governance as a Service**.
#
# - Provide your **API key** to authenticate with watsonx.governance.
# - Optionally, to publish evaluation results to the **Governance Console**, provide the required console credentials (refer to the commented section in the code).

# %%
# --- IBM watsonx.governance Credentials ---
from ibm_watsonx_gov.config import Credentials, WxGovConsoleCredentials

# Load credentials securely from environment variables
CLOUD_API_KEY = "<cloud_api_key>"
# Initialize watsonx.governance credentials
credentials = Credentials(
    api_key=CLOUD_API_KEY,
    # Optional: specify region if not using default (us-south)
    # region="eu-de"
)

# --- Optional: Governance Console Credentials (for publishing evaluation results) ---
WXGC_URL = "https://<server_name>/<basePath>" # Optional: Required only for Governance Console publishing
WXGC_MODEL_ID="MODEL_ID" # Eg : "MOD_0000001"
wx_gc_credentials = WxGovConsoleCredentials(
        url=WXGC_URL,
        username=CLOUD_API_KEY,
        password=CLOUD_API_KEY,
        api_key=CLOUD_API_KEY
    )

# %% [markdown]
# ## Step 2: Configure Credentials  (**IBM watsonx.governance Software**)
#
# Use this cell if you are using the **IBM watsonx.governance Software**.
#
# > ⚠️ **Important:** Do not configure credentials in both Step 1 and Step 2. Use only the appropriate configuration based on your deployment type (Service or Software).

# %%
from ibm_watsonx_gov.config import Credentials, WxGovConsoleCredentials

#--- IBM watsonx.governance Software Credentials ---

WXG_URL = "<watsonx.governance host URL>" #e.g, "https://cpd-cpd-instance.apps.xyzzxyz.cp.fyre.ibm.com/" 
WXG_API_KEY = "<watsonx.governance API key>"
WXG_USERNAME = "<watsonx.governance username>" #e.g, "ccadmin"
WXG_VERSION = "<watsonx.governance version>"  # e.g., "2.1"

credentials = Credentials(
    url=WXG_URL,
    api_key=WXG_API_KEY,
    username=WXG_USERNAME,
    version=WXG_VERSION,
    disable_ssl=False
)

# #--- Optional: Governance Console Credentials (for pushing evaluation results) ---

WXGC_URL = "https://<governance console>/openpages-openpagesinstance-cr-grc"
WXGC_USERNAME = "<console username>"
WXGC_PASSWORD = "<console password>"
WXGC_API_KEY = "<console API key>"

wx_gc_credentials = WxGovConsoleCredentials(
    url=WXGC_URL,
    username=WXGC_USERNAME,
    password=WXGC_PASSWORD,
    api_key=WXGC_API_KEY
)

# %% [markdown]
# ## Parameters for Model Risk Configuration
#
# The following table describes the parameters used to configure model risk evaluation:
#
# | **Name** | **Description** | **Type** | **Default Value** |
# |:--|:--|:--|:--|
# | `model_details` | Specifies the foundation model to evaluate. | `WxAIFoundationModel` or `CustomFoundationModel` | — |
# | `risk_dimensions` *(Optional)* | List of risk dimensions to evaluate. Supported values include:<br>`['prompt-injection', 'jailbreaking', 'harmful-code-generation', 'prompt-leaking', 'hallucination', 'output-bias', 'toxic-output', 'harmful-output', 'exposing-personal-information', 'revealing-confidential-information']`.<br>Note: The following risks use a judging LLM (LLMJ) for evaluation: `"jailbreaking"`, `"harmful-code-generation"`, `"prompt-injection"` You’ll need to provide LLM service credentials (e.g., watsonx.ai) in later setup steps to run these evaluations.. | `list[str]` | `None` |
# | `max_sample_size` *(Optional)* | Maximum number of data instances to evaluate. Use a smaller number (e.g., `50`) for faster evaluation, or set to `None` to evaluate all data for more comprehensive results. | `int` | `None` |
# | `pdf_report_output_path` *(Optional)* | File path to save the generated PDF report. | `str` | `None` |
# | `wx_gc_configuration` *(Optional)* | Configuration for storing evaluation results in the Governance Console. This avoids recomputation by retrieving previously saved metrics. | `WxGovConsoleConfiguration` | `None` |
# | `thresholds` *(Optional)* | Configuration for the threshold used in the pdf report to grade/assign category to the evaluation results of the LLM. By default, the thresholds lower threshold is 25 and upper threshold is 75.  | `Tuple` | `(25,75)` |
#
# ⚠️ Note: Some risks in this evaluation share benchmark datasets. Running both risks in a pair will result in duplicate evaluations. To avoid redundancy: toxic-output and harmful-output share benchmark datasets, and exposing-personal-information and revealing-confidential-information share benchmark datasets. Run only one risk from each pair based on your evaluation goals.

# %% [markdown]
# ### Foundation Model Details
#
# Specify the foundation model to be evaluated. This can be either:
#
# - An IBM watsonx.ai foundation model, or
# - An external foundation model (e.g., from Hugging Face or other providers)
#
# The model name is required when exporting evaluation metrics to a PDF report.

# %%
# Specify the foundation model name for evaluation and PDF report generation
FOUNDATION_MODEL_NAME = "<Foundation_model_name>"

# %% [markdown]
# ### Using IBM watsonx.ai Foundation Models
#
# To evaluate a foundation model hosted on **IBM watsonx.ai**, provide the necessary model details using the `WxAIFoundationModel` class.
#
# - You must specify the model name, model ID, and either a **project ID** or **space ID**.
# - If your watsonx.ai instance is in a different region than watsonx.governance, you may also need to configure a `WxAIModelProvider` with region-specific credentials.
# - Some risk dimensions (e.g., `"prompt-injection"`, `"jailbreaking"`, `"harmful-code-generation"`) require watsonx.ai for evaluation due to their use of LLMJ-based techniques.

# %%
from ibm_watsonx_gov.entities.foundation_model import WxAIFoundationModel
from ibm_watsonx_gov.entities.model_provider import WxAIModelProvider
from ibm_watsonx_gov.config import WxAICredentials
import os

# Specify the foundation model ID (e.g., "ibm/granite-13b-instruct-v1", "meta-llama/llama-3-70b-instruct")
FOUNDATION_MODEL_ID = "ibm/granite-3-3-8b-instruct"


# Provide either a watsonx.ai project ID or space ID
PROJECT_ID = "<project ID"
# SPACE_ID = "<space ID>"

# Optional: Use WxAIModelProvider if watsonx.ai is hosted in a different region than watsonx.governance
# wx_ai_provider = WxAIModelProvider(
#     credentials=WxAICredentials(
#         url="<watsonx.ai region-specific URL>",
#         api_key="<your watsonx.ai API key>"
#     )
# )

# Define the model details
model_details = WxAIFoundationModel(
    model_name=FOUNDATION_MODEL_NAME,
    model_id=FOUNDATION_MODEL_ID,
    project_id=PROJECT_ID,
    # space_id=SPACE_ID,
    # provider=wx_ai_provider
)


# Optional: Set environment variables for LLMJ-based risk evaluations. 
# ⚠️: Not supported for (IBM watsonx.governance Software (CPD))
# These are required for risks like 'prompt-injection', 'jailbreaking', and 'harmful-code-generation'
# os.environ["UNITXT_DEFAULT_PROVIDER"] = "watsonx-sdk"
# os.environ["WML_URL"] = "https://us-south.ml.cloud.ibm.com"
# os.environ["WML_PROJECT_ID"] = PROJECT_ID
# os.environ["WML_APIKEY"] = CLOUD_API_KEY

# %% [markdown]
# ### Using External Foundation Models
#
# To evaluate an external foundation model (e.g., from Hugging Face, Azure, AWS, Replicate, or Together AI), use the `CustomFoundationModel` class.
#
# - You must provide a **custom scoring function** that wraps the model's inference logic.
# - Some risk dimensions (e.g., `"prompt-injection"`, `"jailbreaking"`, `"harmful-code-generation"`) require LLMJ-based evaluation. These models must be hosted on a supported provider (e.g., watsonx.ai, Azure, AWS, etc.).
# - When using LLMJ-based risks with external models, you must configure the appropriate environment variables for your provider.

# %%
# from ibm_watsonx_gov.entities.foundation_model import CustomFoundationModel

# --- Define a scoring function for your external model ---
# ⚠️ Note inputs and output of the scoring function must match the sample Scoring function below

# Example: Scoring function using a Hugging Face model
# from transformers import T5Tokenizer, T5ForConditionalGeneration
# import pandas as pd

# tokenizer = T5Tokenizer.from_pretrained("google/flan-ul2")
# model = T5ForConditionalGeneration.from_pretrained("google/flan-ul2")

# def scoring_fn(data:pd.DataFrame):
#     predictions_list = []
#     for prompt_text in data.iloc[:, 0].values.tolist():
#         input_ids = tokenizer(prompt_text, return_tensors="pt").input_ids
#         output = model.generate(input_ids)
#         output = tokenizer.decode(output[0], skip_special_tokens=True)
#         predictions_list.append(output)
#     return pd.DataFrame({"generated_text": predictions_list})

# model_details = CustomFoundationModel(
#     model_name=FOUNDATION_MODEL_NAME,
#     scoring_fn=scoring_fn
# )




# --- Environment variables for LLMJ-based risk evaluation ---

# If using LLMJ-based risks with external models, set provider-specific credentials:

# Azure (⚠️ ensure the model matches IBM's recommended configuration where the LLMJ is " "meta-llama/llama-3-3-70b-instruct"")
# os.environ["UNITXT_DEFAULT_PROVIDER"] = "azure"
# os.environ["AZURE_AI_API_BASE"] = "<your Azure endpoint>"  # e.g., "https://user-6309-pmmln.eastus2.inference.ml.azure.com/"
# os.environ["AZURE_AI_API_KEY"] = "<your Azure API key>"

# AWS
# os.environ["UNITXT_DEFAULT_PROVIDER"] = "aws"
# os.environ["AWS_ACCESS_KEY_ID"] = "<your AWS access key>"
# os.environ["AWS_SECRET_ACCESS_KEY"] = "<your AWS secret key>"
# os.environ["AWS_REGION_NAME"] = "<your AWS region>"

# Replicate
# os.environ["UNITXT_DEFAULT_PROVIDER"] = "replicate"
# os.environ["REPLICATE_API_TOKEN"] = "<your Replicate API token>"

# Together AI
# os.environ["UNITXT_DEFAULT_PROVIDER"] =  "together-ai"
# os.environ["TOGETHERAI_API_KEY"] = "<your Together AI API key>"

# %% [markdown]
# ### Configure Risk Evaluation Parameters
#
# In this step, you define the parameters for the model risk evaluation:
#
# - `risk_dimensions`: List of risks to evaluate. In this example, only `"hallucination"` is selected.
# - `max_sample_size`: Limits the number of data instances used for evaluation. A smaller number speeds up the process.
# - `pdf_report_output_path`: Directory where the PDF report will be saved.
# - `wx_gc_configuration` *(Optional)*: If you want to store evaluation results in the Governance Console, provide the model ID and credentials.

# %%
from ibm_watsonx_gov.config.model_risk_configuration import WxGovConsoleConfiguration
import os

risk_dimensions = ["hallucination"]
pdf_report_output_path = os.getcwd()

# Start with a small sample size to perform a quick sanity check.
# For a full evaluation with more meaningful results, set max_sample_size = None.
# This will evaluate the entire dataset, which may take several hours depending on the dataset size and selected risks.
max_sample_size = 1


## [Optional] Provide the Governance Console configuration if required to push the result.
# wx_gc_configuration = WxGovConsoleConfiguration(model_id=WXGC_MODEL_ID,credentials=wx_gc_credentials)

# %%
from ibm_watsonx_gov.config.model_risk_configuration import WxGovConsoleConfiguration
import os

risk_dimensions = ["hallucination"]
pdf_report_output_path = os.getcwd()

# Start with a small sample size to perform a quick sanity check.
# For a full evaluation with more meaningful results, set max_sample_size = None.
# This will evaluate the entire dataset, which may take several hours depending on the dataset size and selected risks.
max_sample_size = 1

# %% [markdown]
# ## Foundation Model Risk Evaluation <a name="evaluate"></a>
#
# In this step, you create the **Model Risk Evaluation (MRE) configuration** using the parameters defined earlier.
#
# This configuration includes:
# - The foundation model details
# - Selected risk dimensions
# - Sample size for evaluation
# - Output path for the PDF report
# - *(Optional)* Governance Console configuration to store results
# - *(Optional)* Custom threshold configuration to categorize evaluation results
#
# > ⚠️ **Important:** Evaluation can be time- and resource-intensive. To ensure everything is working correctly before running a full evaluation, we recommend performing a quick sanity check using a small sample size. ex. max_sample_size = 1   risk_dimensions = [ "harmful-code-generation"]

# %%
from ibm_watsonx_gov.config.model_risk_configuration import ModelRiskConfiguration, WxGovConsoleConfiguration

# Create the Model Risk Evaluation (MRE) configuration
configuration = ModelRiskConfiguration(
    model_details=model_details,
    risk_dimensions=risk_dimensions,
    max_sample_size=max_sample_size,
    pdf_report_output_path=pdf_report_output_path,
    
    # Optional: Uncomment to customize thresholds for grading/categorizing results of the evaluation using (lower_threshold, upper_threshold)
    # thresholds=(25, 75),
    
#     # Optional: Uncomment to push results to the Governance Console (OpenPages)
    # wx_gc_configuration=WxGovConsoleConfiguration(credentials=wx_gc_credentials,model_id=FOUNDATION_MODEL_ID)
 )

# %% [markdown]
# ## Evaluate Model Risk
#
# Now that the configuration is complete, you can run the model risk evaluation.
#
# This step will:
# - Initialize the API client using your credentials
# - Create a `ModelRiskEvaluator` instance with the configuration
# - Execute the evaluation and return the results
#
# The output will display the evaluation results in a structured format.

# %%
from ibm_watsonx_gov.clients.api_client import APIClient
from ibm_watsonx_gov.evaluators.model_risk_evaluator import ModelRiskEvaluator

# Initialize the API client
wxgov_client = APIClient(credentials)

# Create the evaluator with the configuration
evaluator = ModelRiskEvaluator(
    configuration=configuration,
    api_client=wxgov_client
)

# Run the evaluation
result = evaluator.evaluate()

# %%
print(result)
# Out:
# risks=[Risk(name='hallucination', benchmarks=[Benchmark(name='cards.value_alignment.hallucinations.truthfulqa', metrics=[RiskMetric(name='score_name', value='rougeL'), RiskMetric(name='score', value=0.207), RiskMetric(name='num_of_instances', value=1.0), RiskMetric(name='sacrebleu', value=0.1), RiskMetric(name='counts', value=2.0), RiskMetric(name='totals', value=15.5), RiskMetric(name='precisions', value=0.13), RiskMetric(name='bp', value=1.0), RiskMetric(name='sys_len', value=17.0), RiskMetric(name='ref_len', value=13.0), RiskMetric(name='rouge1', value=0.345), RiskMetric(name='rougeLsum', value=0.276), RiskMetric(name='rougeL', value=0.207), RiskMetric(name='rouge2', value=0.148)])])] output_file_path='/Users/tharayasmin/Downloads/mra_report_2026-03-09_15-41-42.pdf'

# %% [markdown]
# <!-- ## Display the results <a name="display"></a> -->

# %% [markdown]
# ### Display Evaluation Results as JSON

# %%
result.to_json()
# Out:
# '{"risks":[{"name":"hallucination","benchmarks":[{"name":"cards.value_alignment.hallucinations.truthfulqa","metrics":[{"name":"score_name","value":"rougeL"},{"name":"score","value":0.37},{"name":"num_of_instances","value":1.0},{"name":"sacrebleu","value":0.19},{"name":"counts","value":2.75},{"name":"totals","value":12.5},{"name":"precisions","value":0.212},{"name":"bp","value":1.0},{"name":"sys_len","value":14.0},{"name":"ref_len","value":13.0},{"name":"rougeLsum","value":0.37},{"name":"rougeL","value":0.37},{"name":"rouge1","value":0.37},{"name":"rouge2","value":0.24}]}]}],"output_file_path":"/Users/tharayasmin/Downloads/mra_report_2026-03-05_11-23-49.pdf"}'

# %% [markdown]
# ### Display Evaluation Results in a Table

# %%
# Display the evaluation results in a table format
evaluator.display_table()
# Out:
# --- Risk: hallucination ---
# Benchmark: cards.value_alignment.hallucinations.truthfulqa
#                 name   value
# 0         score_name  rougeL
# 1              score    0.37
# 2   num_of_instances     1.0
# 3          sacrebleu    0.19
# 4             counts    2.75
# 5             totals    12.5
# 6         precisions   0.212
# 7                 bp     1.0
# 8            sys_len    14.0
# 9            ref_len    13.0
# 10         rougeLsum    0.37
# 11            rougeL    0.37
# 12            rouge1    0.37
# 13            rouge2    0.24

# %% [markdown]
# ### Export Evaluation Report to PDF
#
# You can export a comprehensive PDF report of the evaluation results using the method below.
#
# This report includes:
# - A summary of the evaluated risks
# - Additional insights not available in the JSON or tabular output

# %%
# Download the comprehensive PDF report of the evaluation
evaluator.download_model_risk_report()
# Out:
# <a download="/Users/tharayasmin/Downloads/mra_report_2026-03-05_11-23-49.pdf" href="data:text/json;base64,..." target="_blank">Download File</a>

# %% [markdown]
# ## 📎 Appendix
#
# ### 🔑 How to Get the Model ID from the Governance Console
#
# If you're pushing evaluation results to the Governance Console, you'll need a **Model ID**. Here's how to obtain it:
#
# 1. Log in to the **Governance Console**.
# 2. From the left-hand menu, go to **Inventory** → **Models**.
# 3. Click **New** to create a new model entry.
# 4. Fill in the required details.
# 5. In the **General** section, locate the field labeled **Model ID** — copy this value for use in your configuration.
